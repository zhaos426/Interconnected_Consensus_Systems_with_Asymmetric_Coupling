# %% [markdown]
# # Supplementary Fig 1
#
# This notebook creates the sup fig that illustrates how the nonrobust optima arises due to a bifurcation in which two eigenvalues collide to create a complex pair of eigenvalues.

# %%
# %pylab inline 
from numpy import *

import sys
sys.path.append('../utils')
from plot import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
omegas =  array([10**1.5])# coupling strengths
deltas = linspace(-1,1,31)# asymmetry paremeters
print('omega = ',omegas[0])
fig,ax,lgd = plot_ReIm_lambda23('RingGraph4',omegas,deltas)

savefig('figs/supplementary figure1.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# omega =  31.622776601683793
