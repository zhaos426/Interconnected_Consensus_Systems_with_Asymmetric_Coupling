# %% [markdown]
# # Figure 1

# %%
# %pylab inline 
import networkx as nx
import matplotlib.patches as patches

import sys
sys.path.append('../utils')
from network_properties import *
from network_visualization import *
from plot import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Figure1: Network Visualization

# %%
G = get_network_properties('HumanAINetwork')
# G = get_network_properties('Krackhardt-High-Tech')

n = G[0] # number of nodes in each layer


inter_layer_edge_list = [(i,i+n) for i in range(1,n+1)] + [(i+n,i) for i in range(1,n+1)] # 2 layer networks

intra_layer_edge_colors = ['#FF644E','#56C1FF'] 

network_visualization(G,inter_layer_edge_list,intra_layer_edge_colors)
savefig('figs/figure1_HumanAI.pdf')
# Out:
# /Users/zhaosong/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /Users/zhaosong/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %% [markdown]
# ## Figure1: Time Series

# %%
# deltas = [0,.5,0.8] 
deltas = [-.5,0,.5] 
omegas = [30]*len(deltas)
tt = 1200
# G = get_network_properties('RingGraph4')
G = get_network_properties('HumanAINetwork')
dt = .002

fig1,ax = subplots(1,4,figsize=(12,2.6),constrained_layout=True)
errors,x,x_final,x0,lam,uu,idd,supraL = plot_timeseries(ax,G,deltas,omegas,tt,dt)
savefig('figs/figure1_BC.pdf')
